# %% [markdown]
# ##### Trinomial model tests

# %%
#Option parameters
spot  = 100
strike = 100
maturity = 0.5
sigma = 0.2
r = 0.02
type_call = 0
type_put = 1

# %%
#n period test with n=1
from matplotlib import pyplot as plt
from trinomial.n_periods_trinomial_model import n_periods_trinomial_model
from trinomial.n_periods_trinomial_tree import n_periods_trinomial_tree
n=1
call_price = n_periods_trinomial_model(n, sigma, r, spot, maturity, strike, type_call)
put_price = n_periods_trinomial_model(n, sigma, r, spot, maturity, strike, type_put)
figure, axes = plt.subplots(1, 2)
n_periods_trinomial_tree(call_price[0], call_price[2], axes[0], "Call")
n_periods_trinomial_tree(put_price[0], put_price[2], axes[1], "Put")

# %% [markdown]
# ##### Pour n=1, nous obtenons des résultats assez proches de ceux du modèle binomial, donc notre code est fiable.

# %%
#n period test with n=1
from matplotlib import pyplot as plt
from trinomial.n_periods_trinomial_model import n_periods_trinomial_model
from trinomial.n_periods_trinomial_tree import n_periods_trinomial_tree
n=2
call_price = n_periods_trinomial_model(n, sigma, r, spot, maturity, strike, type_call)
put_price = n_periods_trinomial_model(n, sigma, r, spot, maturity, strike, type_put)
figure, axes = plt.subplots(1, 2)
n_periods_trinomial_tree(call_price[0], call_price[2], axes[0], "Call")
n_periods_trinomial_tree(put_price[0], put_price[2], axes[1], "Put")
